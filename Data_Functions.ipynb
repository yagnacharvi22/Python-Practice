# %%
#function w/ parameter without return value

def isPrime1(num):
    count=0
    a=False
    for i in range(1, (num//2)+1):
        if num%i==0:
            count=count+1
    if count==1:
       a=True

b=isPrime1(11)
if b==True:
    print("Prime number")
else:
    print("Not a prime number")
# Out:
# Not a prime number

# %%
#function w/o parameter w/ return value
def isPrime1(num):
    count=0
    a=False
    for i in range(1, (num//2)+1):
        if num%i==0:
            count=count+1
    if count==1:
       a=True
    return a

b=isPrime1(12)
if b==True:
    print("Prime number")
else:
    print("Not a prime number")
# Out:
# Not a prime number

# %%
#3. Function without paramenters and without return value
def isPrime():
    num=int(input("Enter your number :"))
    count=0
    for i in range(1, (num//2)+1):
        if num%i==0:
            count=count+1
    if count==1:
        print(num," is a prime number")
    else:
        print(num," is not a prime number")

isPrime()
# Out:
# Enter your number :222
# 222  is not a prime number

# %%
# 4. Function without paramenters and wit return value
def isPrime1():
    num=int(input("Enter your number"))
    count=0
    a=False
    for i in range(1, (num//2)+1):
        if num%i==0:
            count=count+1
    if count==1:
       a=True
    return a

b=isPrime1()
if b==True:
    print("Prime number")
else:
    print("Not a prime number")
# Out:
# Enter your number6002
# Not a prime number

# %%
def viewPrograms():
    print("1. Prime number program")
    print("2. Reverse of a given number")
    print("3. Print factors of a given number")
    option=int(input("Choose your option: "))
    if option==25:
        isPrime()
    elif option==35:
        reverseNumber()
    elif option==45:
        factors()
    else:
        print("Please select 1 to 3")
def isPrime():
    print("Prime number program")
def reverseNumber():
    print("Reverse number code")
def factors():
    print("Factors code")


viewPrograms()
# Out:
# 1. Prime number program
# 2. Reverse of a given number
# 3. Print factors of a given number
# Choose your option: 25
# Prime number program

# %%
class ATM:
    def viewOptions(self):
        print("Welcome to ABC bank ")
        print("1. Deposit")
        print("2. Withdraw")
        print("3. Balance Enquiry")
        print("0. EXIT")
        option=int(input("Choose your option: "))
obj=ATM()
obj.viewOptions()
# Out:
# Welcome to ABC bank
# 1. Deposit
# 2. Withdraw
# 3. Balance Enquiry
# 0. EXIT
# Choose your option: 2

# %%
class ATM:
    acbal=10000
    def withdraw(self):
      #accept amount
      #amount should be multiples of 100
      #withdraw amount should be less than acbal
      #transaction limit is 20k

    def deposit(self):
        amt=int(input("Enter your deposite amount :"))
        if amt%100==0:
            self.acbal=self.acbal+amt
            if amt<=50000:
              self.acbal=self.acbal+amt
            else:
                print("Transaction limit is 50k only")
        else:
            print("please enter multiples of hundred")
        print("Avaliable bal is: ",self.acbal)


    def viewOptions(self):
        print("Welcome to ABC bank ")
        print("1. Deposit")
        print("2. Withdraw")
        print("3. Balance Enquiry")
        print("0. EXIT")
        option=int(input("Choose your option: "))
        if option==1:
            obj.deposit()


obj=ATM()
obj.viewOptions()
# Out:
# Welcome to ABC bank
# 1. Deposit
# 2. Withdraw
# 3. Balance Enquiry
# 0. EXIT
# Choose your option: 1
# Enter your deposite amount :76000
# Transaction limit is 50k only
# Avaliable bal is:  86000

# %%
class ATM:
    acbal=10000
    def withdraw(self):
      amt=int(input("Enter your withdraw amount :"))
      if amt%100==0:
        if amt<=self.acbal:
            if amt<=20000:
                self.acbal=self.acbal-amt
                print("Avialable balance is:", self.acbal)
                print("Dispensing notes:")

            else:
                print("Transaction limit is 20k only")


        def deposit(self):
         amt=int(input("Enter your deposite amount :"))
        if amt%100==0:
            self.acbal=self.acbal+amt
            if amt<=50000:
              self.acbal=self.acbal+amt
            else:
                print("Transaction limit is 50k only")
        else:
            print("please enter multiples of hundred")
        print("Avaliable bal is: ",self.acbal)


    def viewOptions(self):
        print("Welcome to ABC bank ")
        print("1. Deposit")
        print("2. Withdraw")
        print("3. Balance Enquiry")
        print("0. EXIT")
        option=int(input("Choose your option: "))
        if option==1:
            obj.deposit()
        elif option==2:
             obj.withdraw()

obj=ATM()
obj.viewOptions()
# Out:
# Welcome to ABC bank
# 1. Deposit
# 2. Withdraw
# 3. Balance Enquiry
# 0. EXIT
# Choose your option: 2
# Enter your withdraw amount :50000
# Avaliable bal is:  110000

# %%
class ATM:
    acbal=10000
    def numberOfNotes(self,amt):
        five=0
        two=0
        one=1
        if amt>=500:
            five=amt//500
            amt=amt-(five*500)
            print("500 rupees notes are : ",five)
        if amt>=200:
            two=amt//200
            amt=amt-(two*200)
            print("200 rupees notes are : ",two)
        if amt>=100:
            print("100 rupees notes are  ",one)

    def withdraw(self):
        amt=int(input("Enter your withdraw amount: "))
        if amt%100==0:
            if amt<=self.acbal:
                if amt<=20000:
                    self.acbal=self.acbal-amt
                    obj.numberOfNotes(amt)
                    print("Avaliable bal is: ",self.acbal)
                else:
                    print("Transaction limit is 20k only")
            else:
                print("Insuffcient fund")
        else:
            print("Please enter multiples of 100")
    def deposit(self):
        amt=int(input("Enter your deposite amount :"))
        if amt%100==0:
            if amt<=50000:
                self.acbal=self.acbal+amt
            else:
                print("Transaction limit is 50k only")
        else:
            print("Please enter multiples of 100")
        print("Avaliable bal is: ",self.acbal)


    def viewOptions(self):
        print("Welcome to ABC bank ")
        print("1. Deposit")
        print("2. Withdraw")
        print("3. Balance Enquiry")
        print("0. EXIT")
        option=int(input("Choose your option: "))
        if option==1:
            obj.deposit()
        elif option==2:
            obj.withdraw()
        elif option==3:
          print("Available bal is:",self.acbal)
        elif option==0:
          print("Thank you, Visit again")
        else:
          print("please select correct option")



obj=ATM()
obj.viewOptions()
# Out:
# Welcome to ABC bank
# 1. Deposit
# 2. Withdraw
# 3. Balance Enquiry
# 0. EXIT
# Choose your option: 2
# Enter your withdraw amount: 1500
# 500 rupees notes are :  3
# Avaliable bal is:  8500

# %%
class ATM:
    acbal=10000
    def continue1(self):
        value=int(input("1 for continue and 0 for EXIT"))
        if value==1:
            obj.viewOptions()
        else:
            print("Thank you, Visit again")
    def numberOfNotes(self,amt):
        five=0
        two=0
        one=1
        if amt>=500:
            five=amt//500
            amt=amt-(five*500)
            print("500 rupees notes are : ",five)
        if amt>=200:
            two=amt//200
            amt=amt-(two*200)
            print("200 rupees notes are : ",two)
        if amt>=100:
            print("100 rupees notes are  ",one)

    def withdraw(self):
        amt=int(input("Enter your withdraw amount: "))
        if amt%100==0:
            if amt<=self.acbal:
                if amt<=20000:
                    self.acbal=self.acbal-amt
                    obj.numberOfNotes(amt)
                    print("Avaliable bal is: ",self.acbal)
                else:
                    print("Transaction limit is 20k only")
            else:
                print("Insuffcient fund")
        else:
            print("Please enter multiples of 100")
    def deposit(self):
        amt=int(input("Enter your deposite amount :"))
        if amt%100==0:
            if amt<=50000:
                self.acbal=self.acbal+amt
            else:
                print("Transaction limit is 50k only")
        else:
            print("Please enter multiples of 100")
        print("Avaliable bal is: ",self.acbal)


    def viewOptions(self):
        print("Welcome to ABC bank ")
        print("1. Deposit")
        print("2. Withdraw")
        print("3. Balance Enquiry")
        print("0. EXIT")
        option=int(input("Choose your option: "))
        if option==1:
            obj.deposit()
            obj.continue1()
        elif option==2:
            obj.withdraw()
            obj.continue1()
        elif option==3:
            print("Avaliable bal is: ",self.acbal)
            obj.continue1()
        elif option==0:
            print("Thank you, Visit again")
        else:
            print("Please select correct option ")



obj=ATM()
obj.viewOptions()
# Out:
# Welcome to ABC bank
# 1. Deposit
# 2. Withdraw
# 3. Balance Enquiry
# 0. EXIT
# Choose your option: 3
# Avaliable bal is:  10000
# 1 for continue and 0 for EXIT1
# Welcome to ABC bank
# 1. Deposit
# 2. Withdraw
# 3. Balance Enquiry
# 0. EXIT
# Choose your option: 1
# Enter your deposite amount :4500
# Avaliable bal is:  14500
# 1 for continue and 0 for EXIT1
# Welcome to ABC bank
# 1. Deposit
# 2. Withdraw
# 3. Balance Enquiry
# 0. EXIT
# Choose your option: 2
# Enter your withdraw amount: 2500
# 500 rupees notes are :  5
# Avaliable bal is:  12000
# 1 for continue and 0 for EXIT0
# Thank you, Visit again
